# %%
# Basic analysis of data and shape

import pandas as pd
import numpy as np


base_path = "/Users/shubhamprashar/Desktop/Interview Prep/ml_projects/credit-default-risk/data"
train_path =  base_path + "/application_train.csv"

# pandas -> dataframe is used to read csv
df = pd.read_csv(train_path)

# examples, features(dimensions)
# (307511, 122)
# print(df.shape)
# print(df.head) # prints first few rows
# print(df.columns.tolist()) # prints all the name of dimensions (features) 




# Yes, exactly. df.isna() returns a DataFrame of the same shape with True where a 
# value is null/NaN and False where it's not.
# print(df.isna())

# sums how many null values per column name 
# print(df.isna().sum())

# columns which are categorical and which are numerical
categorical = df.select_dtypes(include='object').shape[1]
numerical = df.select_dtypes(include='number').shape[1]


# unique value per column
# print(df.nunique())

# for every available col this gives the null % 
# print(df.isnull().mean() * 100)


# column name is the index
# Pandas automatically group the data by the index
summary = pd.DataFrame({
    "dtypes" : df.dtypes,
    "categorical" : categorical,
    "numerical" : numerical,
    "missing" : df.isna().sum(),
    "missing_percentage" : df.isna().mean() * 100,
    "unique" : df.nunique()
})

print(summary)
# Out:
#                              dtypes  categorical  numerical  missing  \
# SK_ID_CURR                    int64           16        106        0
# TARGET                        int64           16        106        0
# NAME_CONTRACT_TYPE           object           16        106        0
# CODE_GENDER                  object           16        106        0
# FLAG_OWN_CAR                 object           16        106        0
# ...                             ...          ...        ...      ...
# AMT_REQ_CREDIT_BUREAU_DAY   float64           16        106    41519
# AMT_REQ_CREDIT_BUREAU_WEEK  float64           16        106    41519
# AMT_REQ_CREDIT_BUREAU_MON   float64           16        106    41519
# AMT_REQ_CREDIT_BUREAU_QRT   float64           16        106    41519
# AMT_REQ_CREDIT_BUREAU_YEAR  float64           16        106    41519
#
#                             missing_percentage  unique
# SK_ID_CURR                            0.000000  307511
# ...

# %%
summary[ summary["missing_percentage"] >= 40 ].sort_values(ascending=False, by="missing_percentage")
# Out:
#                                dtypes  categorical  numerical  missing  \
# COMMONAREA_AVG                float64           16        106   214865
# COMMONAREA_MEDI               float64           16        106   214865
# COMMONAREA_MODE               float64           16        106   214865
# NONLIVINGAPARTMENTS_MEDI      float64           16        106   213514
# NONLIVINGAPARTMENTS_MODE      float64           16        106   213514
# NONLIVINGAPARTMENTS_AVG       float64           16        106   213514
# FONDKAPREMONT_MODE             object           16        106   210295
# LIVINGAPARTMENTS_MEDI         float64           16        106   210199
# LIVINGAPARTMENTS_AVG          float64           16        106   210199
# LIVINGAPARTMENTS_MODE         float64           16        106   210199
# FLOORSMIN_MODE                float64           16        106   208642
# FLOORSMIN_MEDI                float64           16        106   208642
# ...

# %%
summary[ summary["missing_percentage"] >= 60 ].sort_values(ascending=False, by="missing_percentage")

#### All these columns are related to how the person is living (buiding)
#### These information may be optional during collection what is why almost 70% of it is missing
# <------- Description of the data that is having high missing percentage ------->
# COMMONAREA_AVG,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 79,application_{train|test}.csv,COMMONAREA_MEDI,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized


# 65,application_{train|test}.csv,COMMONAREA_MODE,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 87,application_{train|test}.csv,NONLIVINGAPARTMENTS_MEDI,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 73,application_{train|test}.csv,NONLIVINGAPARTMENTS_MODE,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 59,application_{train|test}.csv,NONLIVINGAPARTMENTS_AVG,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 89,application_{train|test}.csv,FONDKAPREMONT_MODE,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 87,application_{train|test}.csv,NONLIVINGAPARTMENTS_MEDI,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 57,application_{train|test}.csv,LIVINGAPARTMENTS_AVG,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized

# 71,application_{train|test}.csv,LIVINGAPARTMENTS_MODE,"Normalized information about building where the client lives, What is average (_AVG suffix), modus (_MODE suffix), median (_MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor",normalized
# Out:
#                            dtypes  categorical  numerical  missing  \
# COMMONAREA_MEDI           float64           16        106   214865
# COMMONAREA_AVG            float64           16        106   214865
# COMMONAREA_MODE           float64           16        106   214865
# NONLIVINGAPARTMENTS_MEDI  float64           16        106   213514
# NONLIVINGAPARTMENTS_AVG   float64           16        106   213514
# NONLIVINGAPARTMENTS_MODE  float64           16        106   213514
# FONDKAPREMONT_MODE         object           16        106   210295
# LIVINGAPARTMENTS_AVG      float64           16        106   210199
# LIVINGAPARTMENTS_MEDI     float64           16        106   210199
# LIVINGAPARTMENTS_MODE     float64           16        106   210199
# FLOORSMIN_MEDI            float64           16        106   208642
# FLOORSMIN_MODE            float64           16        106   208642
# FLOORSMIN_AVG             float64           16        106   208642
# ...

# %% [markdown]
# ## Target Distribution
#
# The dataset contains 307,511 loan applications.
#
# 91.9% of applicants belong to class 0 (no payment difficulty).
#
# 8.1% of applicants belong to class 1 (payment difficulty).
#
# This indicates a moderately imbalanced classification problem.

# %%
# Raw count
print(df['TARGET'].value_counts())

# gives ratio rather than count
print(df['TARGET'].value_counts(normalize = True))

# %% [markdown]
# # We will explore the default based on the gender
